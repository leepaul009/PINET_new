# %%
import torch
import numpy as np
import os
from collections import OrderedDict

# %%
######### load pretrained model:
path = os.path.join('../experiments/aicom/models/','310_model.pkl')
checkpoint = torch.load(path, map_location=torch.device("cpu"))

# %%
######### model to be updated:
tar_path = os.path.join('../experiments/aicom/models/','??')
tar_checkpoint = torch.load(tar_path, map_location=torch.device("cpu"))
# Out:
# str

# %%
for idx, (key, val) in enumerate(checkpoint['model'].items()):
    print(key, type(val), val.size())
    #if idx >= 50:
        #break
# Out:
# resizing.conv.cbr_unit.0.weight <class 'torch.Tensor'> torch.Size([64, 3, 7, 7])
# resizing.conv.cbr_unit.0.bias <class 'torch.Tensor'> torch.Size([64])
# resizing.conv.cbr_unit.1.weight <class 'torch.Tensor'> torch.Size([64])
# resizing.conv.cbr_unit.1.bias <class 'torch.Tensor'> torch.Size([64])
# resizing.conv.cbr_unit.1.running_mean <class 'torch.Tensor'> torch.Size([64])
# resizing.conv.cbr_unit.1.running_var <class 'torch.Tensor'> torch.Size([64])
# resizing.conv.cbr_unit.1.num_batches_tracked <class 'torch.Tensor'> torch.Size([])
# resizing.re1.conv1.cbr_unit.0.weight <class 'torch.Tensor'> torch.Size([16, 64, 1, 1])
# resizing.re1.conv1.cbr_unit.0.bias <class 'torch.Tensor'> torch.Size([16])
# resizing.re1.conv1.cbr_unit.1.weight <class 'torch.Tensor'> torch.Size([16])
# resizing.re1.conv1.cbr_unit.1.bias <class 'torch.Tensor'> torch.Size([16])
# resizing.re1.conv1.cbr_unit.1.running_mean <class 'torch.Tensor'> torch.Size([16])
# ...
